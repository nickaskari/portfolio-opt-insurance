# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pymoo.optimize import minimize
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.operators.crossover.sbx import SBX
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.operators.sampling.lhs import LatinHypercubeSampling
from pymoo.termination import get_termination
from pymoo.visualization.scatter import Scatter
import seaborn as sns
from PymooOptimization import PortfolioOptimizationProblem
from distribution_calculator import DistributionCalculator
import multiprocessing
from pymoo.core.problem import StarmapParallelization
from dotenv.main import load_dotenv
import os

load_dotenv(override=True)
# Out:
# True

# %%
end_date = os.getenv("END_TRAIN_DATE")
generations = int(os.getenv("GENERATIONS"))
pop_size = int(os.getenv("POP_SIZE"))
frac_liabilities = float(os.getenv('FRAC_LIABILITIES'))

n_processes = 8  
pool = multiprocessing.Pool(n_processes)
runner = StarmapParallelization(pool.starmap)

# %%
def fetch_data_df():
    df = pd.read_csv('../../data/final_daily_returns_asset_classes.csv', index_col=0)
    df.index = pd.to_datetime(df.index)
    df = df[(df.index <= end_date)]
    return df

# %%
returns_df = fetch_data_df()
asset_names = returns_df.columns.tolist()

assets0 = 1000000
liabilities0 = assets0 * frac_liabilities
alpha = 0.995

dist = DistributionCalculator(returns_df)

simulated_daily_returns, simulated_cumulative_returns = dist.prefered_dist()
simulated_cumulative_lg = dist.prefered_liability_growth()

problem = PortfolioOptimizationProblem(assets0, liabilities0, returns_df, alpha,
                                        simulated_daily_returns, simulated_cumulative_returns, simulated_cumulative_lg, elementwise_runner=runner)
# Out:
# c:\Users\nicka\Desktop\portfolio-opt-insurance\optimization\models\PymooOptimization.py:38: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   yearly_returns = self.returns_df.resample('Y').apply(lambda x: np.prod(1 + x) - 1)

# %%
algorithm = NSGA2(
    pop_size=pop_size,
    sampling=LatinHypercubeSampling(),
    crossover=SBX(prob=0.9, eta=5),
    mutation=PolynomialMutation(prob=0.5, eta=10),
    eliminate_duplicates=False
)

# Define termination criteria
termination = get_termination("n_gen", generations)

# Run optimization
start_time = time.time()
result = minimize(problem,
                    algorithm,
                    termination,
                    seed=42,
                    save_history=True,
                    verbose=True,
                    workers=-1)
end_time = time.time()
pool.close()

print(f"Optimization took {end_time - start_time:.2f} seconds.")
# Out:
# ==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |      100 |      1 |  3.271075E+05 |  1.517294E+06 |             - |             -
#      2 |      200 |      1 |  2.634012E+05 |  8.997877E+05 |             - |             -
#      3 |      300 |      1 |  1.575237E+05 |  6.351398E+05 |             - |             -
#      4 |      400 |      1 |  1.575237E+05 |  4.530040E+05 |             - |             -
#      5 |      500 |      1 |  7.318116E+04 |  3.255343E+05 |             - |             -
#      6 |      600 |      1 |  1.6233809474 |  2.197304E+05 |             - |             -
#      7 |      700 |      1 |  1.6233809474 |  1.292272E+05 |             - |             -
#      8 |      800 |      1 |  1.2449908559 |  6.696330E+04 |             - |             -
#      9 |      900 |      1 |  0.7597621604 |  1.640548E+04 |             - |             -
#     10 |     1000 |      1 |  0.7597621604 |  1.8076405780 |             - |             -
#     11 |     1100 |      1 |  0.4637329161 |  1.4349592111 |             - |             -
#     12 |     1200 |      1 |  0.3785827842 |  1.1770370091 |             - |             -
#     13 |     1300 |      1 |  0.2895481294 |  0.9395982491 |             - |             -
#     14 |     1400 |      1 |  0.2895481294 |  0.7699899641 |             - |             -
#     15 |     1500 |      1 |  0.1838494966 |  0.6334365477 |             - |             -
#     16 |     1600 |      1 |  0.1079677850 |  0.4798584580 |             - |             -
#     17 |     1700 |      1 |  0.1079677850 |  0.3714865806 |             - |             -
#     18 |     1800 |      1 |  0.1079677850 |  0.2969532460 |             - |             -
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[21], line 14
#      12 # Run optimization
#      13 start_time = time.time()
# ---> 14 result = minimize(problem,
#      15                     algorithm,
#      16                     termination,
#      17                     seed=42,
#      18                     save_history=True,
#      19                     verbose=True,
#      20                     workers=-1)
#      21 end_time = time.time()
#      22 pool.close()
#
# File c:\Users\nicka\Desktop\portfolio-opt-insurance\packages\Lib\site-packages\pymoo\optimize.py:67, in minimize(problem, algorithm, termination, copy_algorithm, copy_termination, **kwargs)
#      64     algorithm.setup(problem, **kwargs)
#      66 # actually execute the algorithm
# ---> 67 res = algorithm.run()
#      69 # store the deep copied algorithm in the result object
#      70 res.algorithm = algorithm
#
# File c:\Users\nicka\Desktop\portfolio-opt-insurance\packages\Lib\site-packages\pymoo\core\algorithm.py:138, in Algorithm.run(self)
#     136 def run(self):
#     137     while self.has_next():
# --> 138         self.next()
#     139     return self.result()
#
# File c:\Users\nicka\Desktop\portfolio-opt-insurance\packages\Lib\site-packages\pymoo\core\algorithm.py:159, in Algorithm.next(self)
#     157 if infills is not None:
#     158     self.evaluator.eval(self.problem, infills, algorithm=self)
# --> 159     self.advance(infills=infills)
#     161 # if the algorithm does not follow the infill-advance scheme just call advance
#     162 else:
#     163     self.advance()
#
# File c:\Users\nicka\Desktop\portfolio-opt-insurance\packages\Lib\site-packages\pymoo\core\algorithm.py:229, in Algorithm.advance(self, infills, **kwargs)
#     227     # always advance to the next iteration - except if the algorithm returns False
#     228     if val is None or val:
# --> 229         self._post_advance()
#     231 # if the algorithm has terminated, then do the finalization steps and return the result
#     232 if self.termination.has_terminated():
#
# File c:\Users\nicka\Desktop\portfolio-opt-insurance\packages\Lib\site-packages\pymoo\core\algorithm.py:319, in Algorithm._post_advance(self)
#     316 _hist, _callback, _display = self.history, self.callback, self.display
#     318 self.history, self.callback, self.display = None, None, None
# --> 319 obj = copy.deepcopy(self)
#     321 self.history, self.callback, self.display = _hist, _callback, _display
#     322 self.history.append(obj)
#
# File C:\Program Files\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File C:\Program Files\Python312\Lib\copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File C:\Program Files\Python312\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File C:\Program Files\Python312\Lib\copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File C:\Program Files\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File C:\Program Files\Python312\Lib\copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File C:\Program Files\Python312\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File C:\Program Files\Python312\Lib\copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File C:\Program Files\Python312\Lib\copy.py:143, in deepcopy(x, memo, _nil)
#     141 copier = getattr(x, "__deepcopy__", None)
#     142 if copier is not None:
# --> 143     y = copier(memo)
#     144 else:
#     145     reductor = dispatch_table.get(cls)
#
# MemoryError: Unable to allocate 269. MiB for an array with shape (20000, 252, 7) and data type float64

# %% [markdown]
# ## Storing The Result For Further Analysis

# %%
from utils.append_to_json import append_to_json

# %%
if result is None or result.X is None:
    risk_measure = os.getenv("RISK_MEASURE")
    distribution = os.getenv("DISTRIBUTION")
    with open("log.txt", "a") as log_file:  # Open in append mode
        log_file.write(f"[{time.strftime('%Y-%m-%d %H:%M:%S')}] ERROR: 'result' is None. Config:", end_date, "|", risk_measure, "|", distribution, "\n")
    print("ERROR: 'result' is None. Logged the issue to log.txt.")

# %%
solutions = []
for i in range(len(result.X)):
    solution = {
        "weights": result.X[i].tolist(),
        "expected_return": -result.F[i, 1],
        "SCR_risk": result.F[i, 0],
        "risk_measure": os.getenv("RISK_MEASURE"),
        "distribution": os.getenv("DISTRIBUTION"),
        "period": (os.getenv("END_TRAIN_DATE"), os.getenv("END_SIMULATION_DATE"))
    }
    solutions.append(solution)

# Define the file path to store the results
json_file_path = "../pareto_front_results.json"

# Save the solutions to the JSON file
append_to_json(json_file_path, {
    "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
    "solutions": solutions
})

print(f"Results saved to {json_file_path}")
# Out:
# Results saved to ../pareto_front_results.json

# %%
plot = Scatter()
plot.add(result.F, label="Pareto Front")

plt.figure(figsize=(8, 6))  # Create a new figure
plt.scatter(result.F[:, 0], -result.F[:, 1], label="Pareto Front")
plt.title("Pareto Front: SCR vs Expected Return")
plt.xlabel("Solvency Capital Requirement (SCR)")
plt.ylabel("Expected Return")

plt.legend()
plt.grid(True)
plt.show()

# %%
best_index = np.argmin(result.F[:, 0])  
best_weights = result.X[best_index]

plt.figure(figsize=(10, 6))
plt.barh(asset_names, best_weights)
plt.title("Portfolio with the least SCR")
plt.xlabel("Weight")
plt.ylabel("Assets")
plt.grid(True)

# For the x-axis, you can still avoid scientific notation if needed
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False)  # For x-axis only

plt.show()

# %%
best_index = np.argmin(result.F[:, 1])  # Maximize expected return (Most risky)
best_weights = result.X[best_index]

plt.figure(figsize=(10, 6))
plt.barh(asset_names, best_weights)
plt.title("Portfolio with the most expected return")
plt.xlabel("Weight")
plt.ylabel("Assets")
plt.grid(True)

# For the x-axis, you can still avoid scientific notation if needed
plt.gca().get_xaxis().get_major_formatter().set_useOffset(False)  # For x-axis only

plt.show()

# %%
print("\nBest Portfolio Allocation by Asset:")
portfolio_allocation = {asset: weight for asset, weight in zip(asset_names, best_weights)}
for asset, weight in portfolio_allocation.items():
    print(f"{asset}: {round(weight, 2)}")

print("Sum of weights:", np.sum(best_weights))

scr = abs(problem.calculate_scr(best_weights))
expected_return = problem.calculate_expected_return(best_weights)
print("\nExpected return over 1 year:", round(expected_return, 2))
print("\nSolvency Capital Requirement (SCR):", round(scr))
# Out:
# Best Portfolio Allocation by Asset:
# REEL: 0.14
# PE: 0.04
# MSCIWORLD: 0.18
# IG: 0.21
# GOV: 0.33
# HY: 0.07
# EONIA: 0.03
# Sum of weights: 0.9999666452807902
#
# Expected return over 1 year: 58058.66
#
# Solvency Capital Requirement (SCR): 291679

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(result.X, annot=False, cmap="Blues", xticklabels=asset_names, yticklabels=False)
plt.title("Heatmap of Portfolio Weights Across Pareto Front Solutions")
plt.xlabel("Assets")
plt.ylabel("Solutions on Pareto Front")
plt.show()

# %%
n_gen = len(result.history)
cv_min = [entry.pop.get("F").min(axis=0) for entry in result.history]

# Separate the two objective functions (assuming index 0 corresponds to SCR and 1 to Expected Return)
scr_min = [f[0] for f in cv_min]
expected_return_min = [f[1] for f in cv_min]

# Plotting
fig, ax1 = plt.subplots(figsize=(8, 6))

# Plot SCR on left y-axis
scr_line, = ax1.plot(range(1, n_gen + 1), scr_min, label="Minimum SCR")
ax1.set_xlabel("Generation")
ax1.set_ylabel("Minimum SCR")
ax1.tick_params(axis='y')

# Create a second y-axis for Expected Return
ax2 = ax1.twinx()
expected_return_line, = ax2.plot(range(1, n_gen + 1), expected_return_min, label="Minimum Expected Return", color='red')
ax2.set_ylabel("Minimum Expected Return (negative)")
ax2.tick_params(axis='y')

# Combine the legends from both axes
lines = [scr_line, expected_return_line]
ax1.legend(lines, [line.get_label() for line in lines], loc="upper right")

# Add title and grid
plt.title("Convergence Over Generations")
fig.tight_layout()
plt.grid(True)
plt.show()

# %%
#problem2 = PortfolioOptimizationProblem(assets0, liabilities0, returns_df.iloc[:, :2], alpha, simulated_daily_returns, simulated_cumulative_returns)

# %% [markdown]
# ## Plotting The Objective Space

# %%
'''
# Assuming we have the two assets (Asset 1 and Asset 2)
# Create a grid of portfolio weights for Asset 1 (weights for Asset 2 will be 1 - w1)
w1_grid = np.linspace(0, 1, 100)  # Asset 1 weights from 0 to 1
w2_grid = 1 - w1_grid  # Asset 2 weights (since their sum must be 1)

# Initialize lists to store SCR and Expected Return for each portfolio combination
scr_values = []
expected_return_values = []

# Loop through each weight combination
for w1, w2 in zip(w1_grid, w2_grid):
    weights = np.array([w1, w2])
    
    # Calculate the SCR and Expected Return using your functions
    scr = abs(problem2.calculate_scr(weights))
    expected_return = problem2.calculate_expected_return(weights)
    
    # Store the calculated values
    scr_values.append(scr)
    expected_return_values.append(expected_return)

# Convert to numpy arrays for easy plotting
scr_values = np.array(scr_values)
expected_return_values = np.array(expected_return_values)

# Plot the SCR vs Expected Return as a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(scr_values, expected_return_values, c=w1_grid, cmap='viridis')
plt.colorbar(label='Asset 1 Weight')
plt.title("Objective Space: SCR vs Expected Return")
plt.xlabel("Solvency Capital Requirement (SCR)")
plt.ylabel("Expected Return")
plt.grid(True)
plt.show() 
'''
# Out:
# '\n# Assuming we have the two assets (Asset 1 and Asset 2)\n# Create a grid of portfolio weights for Asset 1 (weights for Asset 2 will be 1 - w1)\nw1_grid = np.linspace(0, 1, 100)  # Asset 1 weights from 0 to 1\nw2_grid = 1 - w1_grid  # Asset 2 weights (since their sum must be 1)\n\n# Initialize lists to store SCR and Expected Return for each portfolio combination\nscr_values = []\nexpected_return_values = []\n\n# Loop through each weight combination\nfor w1, w2 in zip(w1_grid, w2_grid):\n    weights = np.array([w1, w2])\n    \n    # Calculate the SCR and Expected Return using your functions\n    scr = abs(problem2.calculate_scr(weights))\n    expected_return = problem2.calculate_expected_return(weights)\n    \n    # Store the calculated values\n    scr_values.append(scr)\n    expected_return_values.append(expected_return)\n\n# Convert to numpy arrays for easy plotting\nscr_values = np.array(scr_values)\nexpected_return_values = np.array(expected_return_values)\n\n# Plot the SCR vs Expected Return as a scatter plot\nplt.figure(figsize=(8, 6))\nplt.scatter(scr_values, expected_return_values, c=w1_grid, cmap=\'viridis\')\nplt.colorbar(label=\'Asset 1 Weight\')\nplt.title("Objective Space: SCR vs Expected Return")\nplt.xlabel("Solvency Capital Requirement (SCR)")\nplt.ylabel("Expected Return")\nplt.grid(True)\nplt.show() \n'
