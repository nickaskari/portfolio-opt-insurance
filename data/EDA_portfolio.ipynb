# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly as py
import plotly.express as px
import plotly.io as pio

# %%
df = pd.read_csv('asset_classes.csv')

df.head()
# Out:
#   Exchange Date  ACWI.World.Equities  AGGG.World.Debt  AHYG.Asia.Debt  \
# 0    2024-10-10               119.41           4.3990            6.70
# 1    2024-10-09               119.53           4.3965            6.68
# 2    2024-10-08               119.04           4.4055            6.68
# 3    2024-10-07               118.73           4.4050            6.69
# 4    2024-10-04               119.48           4.4075            6.69
#
#    BWX.World.Debt  EDIV.EmergingMarkets.Equities  \
# 0          22.500                          37.05
# 1          22.515                          36.94
# 2          22.655                          37.21
# 3          22.655                          37.96
# 4          22.700                          37.56
#
#    EEM.EmergingMarkets.Equities  EFA.World.Equities  \
# 0                         46.03               81.88
# 1                         45.94               81.98
# 2                         46.19               81.96
# ...

# %%
normalized_df = pd.read_csv('normalized_asset_classes.csv')

# %%
pio.renderers.default = 'browser'

px.line(df, x='Exchange Date', y= ['ACWI.World.Equities', 
                                   'SPY.US.Equities',
                                   'EDIV.EmergingMarkets.Equities', 
                                   'EFA.World.Equities', 
                                   'PSP.World.PrivateEquity',
                                   'EWG.Europe.Equities'
                                   ]).show()

# %%
pio.renderers.default = 'browser'

px.line(normalized_df, x='Exchange Date', y=['ACWI.World.Equities',
                                             'SPY.US.Equities',
                                             'EDIV.EmergingMarkets.Equities',
                                             'EFA.World.Equities',
                                             'PSP.World.PrivateEquity',
                                             'EWG.Europe.Equities'
                                             ]).show()

# %%
#calculate daily return of SPY, remember that top row is the latest date

new_df = df[['Exchange Date', 'SPY.US.Equities']]

new_df['Percentage Gain'] = df['SPY.US.Equities'].iloc[::-1].pct_change(fill_method=None) * 100

new_df.head()
# Out:
# /var/folders/4j/dxkybcjx57g2_q7pvt8nkd040000gn/T/ipykernel_2477/959912549.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Exchange Date  SPY.US.Equities  Percentage Gain
# 0    2024-10-10           576.13        -0.175001
# 1    2024-10-09           577.14         0.692639
# 2    2024-10-08           573.17         0.945756
# 3    2024-10-07           567.80        -0.904046
# 4    2024-10-04           572.98         0.908739

# %%
#plot the distribution of daily return for SPY

px.histogram(new_df, x='Percentage Gain').show()

# %%
# find the date of the highest and lowest daily return

highest_return = new_df['Percentage Gain'].max()

highest_return_date = new_df[new_df['Percentage Gain'] == highest_return]['Exchange Date']

lowest_return = new_df['Percentage Gain'].min()

lowest_return_date = new_df[new_df['Percentage Gain'] == lowest_return]['Exchange Date']

print(f'The highest daily return for SPY is {highest_return:.2f}% on {highest_return_date}')

print(
    f'The lowest daily return for SPY is {lowest_return:.2f}% on {lowest_return_date}')
# Out:
# The highest daily return for SPY is 9.06% on 1187    2020-03-24
# Name: Exchange Date, dtype: object
# The lowest daily return for SPY is -10.94% on 1193    2020-03-16
# Name: Exchange Date, dtype: object
